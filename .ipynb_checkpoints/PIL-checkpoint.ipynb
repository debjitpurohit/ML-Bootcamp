# %%
from PIL import Image
Image.open("strange.jpeg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=281x355 at 0x1B3F6195BE0>

# %%
# for checking the pixels for strange.jpeg image
# (355,281,3) means let say 3 sqaure shaped layers(those are RED,GREEN,BLUE)  having 355 rows and 281 columns
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
pil = Image.open("strange.jpeg")
arr = np.array(pil)
arr.shape
# Out:
# (355, 281, 3)

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=281x355 at 0x2E7FF426208>

# %%
#initial 5 pixel
cut = arr[:5,:5]
plt.imshow(cut)
